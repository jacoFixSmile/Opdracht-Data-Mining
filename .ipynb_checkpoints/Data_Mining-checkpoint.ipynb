# %%
import sys
import findspark
import pyspark
# !pip install folium
import folium
WhoIsWorking="Daan"
if(WhoIsWorking=="Daan"):
    findspark.init("c:/Users/Eigenaar/spark-3.1.2-bin-hadoop3.2")
else:
    findspark.init("C:\\spark-3.1.2-bin-hadoop3.2\\spark-3.1.2-bin-hadoop3.2")
# Out:
# Requirement already satisfied: folium in c:\users\eigenaar\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: requests in c:\users\eigenaar\anaconda3\lib\site-packages (from folium) (2.25.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\eigenaar\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in c:\users\eigenaar\anaconda3\lib\site-packages (from folium) (1.19.5)
# Requirement already satisfied: branca>=0.3.0 in c:\users\eigenaar\anaconda3\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\eigenaar\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\eigenaar\anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\eigenaar\anaconda3\lib\site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\eigenaar\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eigenaar\anaconda3\lib\site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\eigenaar\anaconda3\lib\site-packages (from requests->folium) (1.26.4)

# %%
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.sql.types import *
from pyspark.sql.functions import avg
from ipywidgets import widgets, interact, interactive, fixed, interact_manual
from pyspark.sql.functions import col
import seaborn as sns
from IPython.display import HTML
import matplotlib.pyplot as plt
spark = SparkSession.builder.getOrCreate()
sqlContext = SQLContext(spark)#Running Query

# %%
#Creating schema's
schema_pubs = StructType([
    StructField("Food Standard Agency's ID", StringType(), nullable=True),
    StructField("name", StringType(), nullable=True),
    StructField("address", StringType(), nullable=True),
    StructField("postcode", StringType(), nullable=True),
    StructField("easting", DoubleType(), nullable=True),
    StructField("northing", DoubleType(), nullable=True),
    StructField("latitude", DoubleType(), nullable=False),
    StructField("longitude", DoubleType(), nullable=False),
    StructField("local_authority", StringType(), nullable=True)

])

# %%
# importing data 

### casualtiesData_df geeft meer info over het slachtoffer
if(WhoIsWorking=="Daan"):
    casualtiesData_df = spark.read.format('csv').option('header', True).load('Kaggle_datasets/Casualties0514.csv')
    accidentData_df = spark.read.format('csv').option('header',True).load('Kaggle_datasets/Accidents0514.csv')
    pubsData_df = spark.read.format('csv').option('header',False).schema(schema_pubs).load('open_pubs.csv')
else:
    accidentData_df = spark.read.format('csv').option('header',True).load('../../../Desktop/Data mining/Accidents0514.csv')
    pubsData_df = spark.read.format('csv').option('header',False).schema(schema_pubs).load('open_pubs.csv')
    casualtiesData_df = spark.read.format('csv').option('header', True).load('../../../Desktop/Data mining/Casualties0514.csv')

# %%
### Filter de pub data set
counterRowsBeforePubs=pubsData_df.count()
pubsData_df=pubsData_df.dropna(subset=["latitude","longitude"])
print(counterRowsBeforePubs-pubsData_df.count()," rijen zijn verwijderd omdat ze lege waarden hadden.")
### nutteloze kolommen zoals Pedestrian_Crossing,Special_Condition_at_site, Carriageway_Hazards,  want volgens Kaggle hebben bijna alle records dezelfde data dus veel gaat deze kolom ons niet opleveren alleen maar een langere run time. heb ook Location_Northing_OSGR, Location_Easting_OSGR, Local_Authority_(District), Local_Authority_(Highway)1st_Road_Class, 1st_Road_Number, 2nd_Road_Class, 2nd_Road_Number, Pedestrian_Crossing-Human_Control, Pedestrian_Crossing-Physical_Facilities
accidentData_df = accidentData_df.drop("Pedestrian_Crossing", "Special_Condition_at_site","Local_Authority_(Highway)", "Carriageway_Hazards","Location_Northing_OSGR", "Location_Easting_OSGR", "Local_Authority_(District)", "Local_Authority_(Highway)1st_Road_Class", "1st_Road_Number", "2nd_Road_Class", "2nd_Road_Number", "Pedestrian_Crossing-Human_Control", "Pedestrian_Crossing-Physical_Facilities")
### In casualtiesData heb ik ook een paar kolommen verwijderd => Pedestian_Location, Pedestrian_Movement, Bus_or_Coach_, Vehicle_Reference, Casualty_Reference, Age_Band_of_Casualty, Pedestrian_Road_Maintenance_Worker, Casualty_Home_Area_Type
casualtiesData_df = casualtiesData_df.drop("Pedestian_Location", "Pedestrian_Movement", "Bus_or_Coach_Passenger", "Vehicle_Reference", "Casualty_Reference", "Age_Band_of_Casualty", "Pedestrian_Road_Maintenance_Worker","Casualty_Home_Area_Type" )
print("Kolommen Vehicle_Reference en Casualty_Reference zijn zeer nuttige gegevens maar die waarden komen precies niet overeen met die tabel op Kaggle dus heb ze weggelaten. Kan dat ik verkeerd ben maar heb niets gevonden.")
# Out:
# 146  rijen zijn verwijderd omdat ze lege waarden hadden.
# Kolommen Vehicle_Reference en Casualty_Reference zijn zeer nuttige gegevens maar die waarden komen precies niet overeen met die tabel op Kaggle dus heb ze weggelaten. Kan dat ik verkeerd ben maar heb niets gevonden.

# %%
### Filter de accident data set
counterRowsBeforePubs=accidentData_df.count()
accidentData_df=accidentData_df.na.drop()
print(counterRowsBeforePubs-accidentData_df.count()," rijen zijn verwijderd omdat ze lege waarden hadden.")

### Filter de casaulties data
counterRowsBeforeCasaul=casualtiesData_df.count()
casualtiesData_df=casualtiesData_df.na.drop()
print(counterRowsBeforeCasaul-casualtiesData_df.count()," rijen zijn verwijderd omdat ze lege waarden hadden.")
# Out:
# 120599  rijen zijn verwijderd omdat ze lege waarden hadden.
# 0  rijen zijn verwijderd omdat ze lege waarden hadden.

# %%
accidentData_df.show(5, vertical=True)
# Out:
# -RECORD 0----------------------------------------------------
#  Accident_Index                              | 200501BS00001
#  Longitude                                   | -0.191170
#  Latitude                                    | 51.489096
#  Police_Force                                | 1
#  Accident_Severity                           | 2
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 04/01/2005
#  Day_of_Week                                 | 3
#  Time                                        | 17:42
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 0
#  Junction_Control                            | -1
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 2
#  Road_Surface_Conditions                     | 2
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01002849
# -RECORD 1----------------------------------------------------
#  Accident_Index                              | 200501BS00002
#  Longitude                                   | -0.211708
#  Latitude                                    | 51.520075
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 05/01/2005
#  Day_of_Week                                 | 4
#  Time                                        | 17:36
#  1st_Road_Class                              | 4
#  Road_Type                                   | 3
#  Speed_limit                                 | 30
#  Junction_Detail                             | 6
#  Junction_Control                            | 2
#  Light_Conditions                            | 4
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01002909
# -RECORD 2----------------------------------------------------
#  Accident_Index                              | 200501BS00003
#  Longitude                                   | -0.206458
#  Latitude                                    | 51.525301
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 06/01/2005
#  Day_of_Week                                 | 5
#  Time                                        | 00:15
#  1st_Road_Class                              | 5
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 0
#  Junction_Control                            | -1
#  Light_Conditions                            | 4
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01002857
# -RECORD 3----------------------------------------------------
#  Accident_Index                              | 200501BS00004
#  Longitude                                   | -0.173862
#  Latitude                                    | 51.482442
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 07/01/2005
#  Day_of_Week                                 | 6
#  Time                                        | 10:35
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 0
#  Junction_Control                            | -1
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01002840
# -RECORD 4----------------------------------------------------
#  Accident_Index                              | 200501BS00005
#  Longitude                                   | -0.156618
#  Latitude                                    | 51.495752
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 10/01/2005
#  Day_of_Week                                 | 2
#  Time                                        | 21:13
#  1st_Road_Class                              | 6
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 0
#  Junction_Control                            | -1
#  Light_Conditions                            | 7
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 2
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01002863
# only showing top 5 rows

# %%
pubsData_df.show(5, vertical=True)
# Out:
# -RECORD 0-----------------------------------------
#  Food Standard Agency's ID | 24
#  name                      | Angel Inn
#  address                   | 43 Friars Street,...
#  postcode                  | CO10 2AG
#  easting                   | 587207.0
#  northing                  | 241058.0
#  latitude                  | 52.036312
#  longitude                 | 0.727924
#  local_authority           | Babergh
# -RECORD 1-----------------------------------------
#  Food Standard Agency's ID | 33
#  name                      | Ark Bar Restaurant
#  address                   | Ark Bar And Resta...
#  postcode                  | CO11 1RH
#  easting                   | 610194.0
#  northing                  | 233329.0
#  latitude                  | 51.958698
#  longitude                 | 1.057832
#  local_authority           | Babergh
# -RECORD 2-----------------------------------------
#  Food Standard Agency's ID | 60
#  name                      | Black Boy
#  address                   | Black Boy Hotel, ...
#  postcode                  | CO10 2EA
#  easting                   | 587356.0
#  northing                  | 241327.0
#  latitude                  | 52.038685
#  longitude                 | 0.730226
#  local_authority           | Babergh
# -RECORD 3-----------------------------------------
#  Food Standard Agency's ID | 61
#  name                      | Black Horse
#  address                   | Lower Street, Str...
#  postcode                  | CO7 6JS
#  easting                   | 604270.0
#  northing                  | 233920.0
#  latitude                  | 51.966211
#  longitude                 | 0.972091
#  local_authority           | Babergh
# -RECORD 4-----------------------------------------
#  Food Standard Agency's ID | 62
#  name                      | Black Lion
#  address                   | Lion Road, Glemsf...
#  postcode                  | CO10 7RF
#  easting                   | 582750.0
#  northing                  | 248298.0
#  latitude                  | 52.102815
#  longitude                 | 0.666893
#  local_authority           | Babergh
# only showing top 5 rows

# %%
#Creating Table
pubsData_df.registerTempTable('pubsTable')
accidentData_df.registerTempTable('accidentTable')
#Running Query
df1 = sqlContext.sql("SELECT COUNT(local_authority) as count,local_authority from pubsTable group by local_authority order by count")
df2 = sqlContext.sql("SELECT COUNT(Number_of_Casualties) as count_casulties,SPEED_LIMIT FROM accidentTable group by SPEED_LIMIT order by SPEED_LIMIT")
## type sql dataframe .collect to get list

# %%
list_casulties_speed=[]
list_speed_casulties=[]
for x in df2.collect():
    list_casulties_speed.append(x[0])
    list_speed_casulties.append(int(x[1]))
print(list_casulties_speed)
plt.bar(list_speed_casulties,list_casulties_speed)
plt.title("Aantal gevallen per snelheids drempel")
plt.xlabel('Snelheid')
plt.ylabel('Aantal Slachtoffers')
plt.show()
# Out:
# [4, 2, 16160, 983411, 128365, 49398, 229611, 113047]

# %%
local_authority=[]
for row in df1.collect():
    local_authority.append(row.local_authority)

# %%
choose_local_authority = widgets.Dropdown(
    options=local_authority,
    value='Isles of Scilly',
    description='Authority:',
)

def load_map_points(local_authority):
    df1 = sqlContext.sql("SELECT * from pubsTable where local_authority='"+local_authority+"'")
    local_authority_coordinates = (df1.collect()[0].latitude,df1.collect()[0].longitude)
    map = folium.Map(location=local_authority_coordinates, zoom_start=11.5)
    ## testing 
    counter=0
    for row in df1.collect():
        folium.Marker(location = [row.latitude,row.longitude]).add_to(map)
    display(map)
def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        load_map_points(change['new'])
choose_local_authority.observe(on_change)
display(display(choose_local_authority))
# Out:
# Dropdown(description='Authority:', options=('Isles of Scilly', 'East Renfrewshire', 'Orkney Islands', 'Na h-Ei…
# None

# %%
### twee dataframes in één dataframe joinen m.b.v. ID(Accident_Index). Beide dataframes hebben evenveel records.
joined = accidentData_df.alias("A").join(casualtiesData_df.alias("B"),col("A.Accident_Index") == col("B.Accident_Index"),"inner").select(col("A.Accident_Index"), col("A.Longitude"),col("A.Latitude"), col("A.Police_Force"), col("A.Accident_Severity"), col("A.Number_of_Vehicles"), col("A.Number_of_Casualties"), col("A.Date"), col("A.Day_of_Week"),col("A.Time"), col("A.1st_Road_Class"), col("A.Road_Type"), col("A.Speed_limit"), col("A.Junction_Detail"), col("A.Junction_Control"), col("A.Light_Conditions"), col("A.Weather_Conditions"), col("A.Road_Surface_Conditions"), col("A.Special_Conditions_at_Site"), col("A.Urban_or_Rural_Area"), col("A.Did_Police_Officer_Attend_Scene_of_Accident"), col("A.LSOA_of_Accident_Location"), col("B.Casualty_Class"), col("B.Sex_of_Casualty"), col("B.Age_of_Casualty"), col("B.Casualty_Severity"), col("B.Pedestrian_Location"), col("B.Car_Passenger"), col("B.Casualty_Type")).toDF("Accident_Index", "Longitude","Latitude","Police_Force", "Accident_Severity","Number_of_Vehicles", "Number_of_Casualties", "Date", "Day_of_Week","Time","1st_Road_Class", "Road_Type", "Speed_limit","Junction_Detail", "Junction_Control","Light_Conditions", "Weather_Conditions","Road_Surface_Conditions","Special_Conditions_at_Site","Urban_or_Rural_Area", "Did_Police_Officer_Attend_Scene_of_Accident", "LSOA_of_Accident_Location","Casualty_Class","Sex_of_Casualty","Age_of_Casualty","Casualty_Severity","Pedestrian_Location","Car_Passenger","Casualty_Type")

# %%
### Soorten voertuigen
from collections import Counter
from pyspark.sql.functions import count

joined.groupby("Casualty_Type").count().show(22)
print("Ongeveer 83% van alle accidenten werden veroorzaakt in een auto (Casualty_Type 9). Andere voertuigen zijn vooral brommers onderverdeeld in groepen (50cc, 125cc, 500cc enzo) andere voertuigen zijn wel een beetje raar boerderij voertuigen? taxi? trambestuurders? zelfs paarden. Kans dat er iemand met een paard naar een pub gaat is vrij klein denk ik. Dus wat doen wij? enkel autos en brommers bijhouden en de rest verwijderen of gewoon zo laten?")
# Out:
# +-------------+-------+
# |Casualty_Type|  count|
# +-------------+-------+
# |           11|  57485|
# |            3|  63957|
# |            8|  28020|
# |           22|    331|
# |           16|   1116|
# |            0| 251398|
# |           98|     50|
# |            5|  80881|
# |           18|    102|
# |           17|   1007|
# |           90|   9338|
# |           19|  45911|
# |           23|     17|
# |           97|    193|
# |            9|1270126|
# |            1| 169654|
# |           20|   5500|
# |           10|   6767|
# |            4|  22117|
# |           21|  11037|
# |            2|  33572|
# +-------------+-------+
#
# Ongeveer 83% van alle accidenten werden veroorzaakt in een auto (Casualty_Type 9). Andere voertuigen zijn vooral brommers onderverdeeld in groepen (50cc, 125cc, 500cc enzo) andere voertuigen zijn wel een beetje raar boerderij voertuigen? taxi? trambestuurders? zelfs paarden. Kans dat er iemand met een paard naar een pub gaat is vrij klein denk ik. Dus wat doen wij? enkel autos en brommers bijhouden en de rest verwijderen of gewoon zo laten?

# %%
### Casualty Class
joined.groupby("Casualty_Class").count().show()
print("Casualty_Class geeft aan of de persoon in kwestie een passagier(2), bestuurder van een voertuig(1) of een voetganger(3) is. Aangezien wij opzoek zijn naar accidenten die werden veroorzaakt door dronken mensen, lijkt het mij onwaarschijnlijk dat passagiers van voertuigen de oorzaak kunnen zijn van een accident dus ik dacht misschien Casualty_Class(2) weglaten?")
# Out:
# +--------------+-------+
# |Casualty_Class|  count|
# +--------------+-------+
# |             3| 251398|
# |             1|1307284|
# |             2| 499897|
# +--------------+-------+
#
# Casualty_Class geeft aan of de persoon in kwestie een passagier(2), bestuurder van een voertuig(1) of een voetganger(3) is. Aangezien wij opzoek zijn naar accidenten die werden veroorzaakt door dronken mensen, lijkt het mij onwaarschijnlijk dat passagiers van voertuigen de oorzaak kunnen zijn van een accident dus ik dacht misschien Casualty_Class(2) weglaten?

# %%
### Leeftijd
joined.groupby("Age_of_Casualty").count().show(121)
print("Er zitten hier records van kinderen 3, 8 jaar enzo. in die andere excel bestand die jij hebt gestuurd was alle info over 16+ mensen. Dus hier weeral al die kinderen verwijderen? Age_of_Casualty met waarde -1 zijn gevallen waar de leeftijd niet gekend is")
# Out:
# +---------------+-----+
# |Age_of_Casualty|count|
# +---------------+-----+
# |             51|22497|
# |              7|10372|
# |             54|19253|
# |             -1|45488|
# |             15|21030|
# |             11|18280|
# |            101|    2|
# |             29|38486|
# |             69| 8114|
# |             42|33251|
# |             73| 6948|
# |             87| 2511|
# |             64|11110|
# |              3| 7515|
# |             30|45375|
# |             34|33905|
# |             59|15507|
# |              8|11348|
# |             28|41181|
# |             22|54072|
# |             85| 3727|
# |             35|37741|
# |             52|21720|
# |             16|38820|
# |              0| 1715|
# |             71| 7175|
# |             98|   71|
# |             47|27522|
# |             99|   70|
# |             96|  145|
# |             43|32014|
# |              5| 8934|
# |             31|35359|
# |            100|    4|
# |             18|72211|
# |             70| 9663|
# |             61|13479|
# |             27|42096|
# |             75| 7338|
# |             17|60964|
# |             26|45473|
# |             46|28971|
# |             78| 5903|
# |             77| 6005|
# |             89| 1686|
# |              6| 9714|
# |             68| 8470|
# |             60|17396|
# |             90| 1374|
# |             19|66776|
# |             23|51806|
# |             41|32725|
# |            102|    2|
# |             55|19747|
# |             93|  487|
# |             95|  244|
# |             40|39055|
# |             38|33498|
# |            103|    1|
# |             25|50818|
# |             44|31011|
# |             82| 4953|
# |             53|20337|
# |             92|  730|
# |             86| 2940|
# |             58|16375|
# |             81| 5093|
# |             33|34461|
# |             48|27148|
# |             97|   96|
# |             67| 9029|
# |             84| 4010|
# |             79| 5781|
# |              9|12515|
# |             24|48720|
# |             32|35508|
# |             88| 1980|
# |              1| 4355|
# |             20|63995|
# |             56|17824|
# |             36|33286|
# |             10|14487|
# |             37|32580|
# |             49|25370|
# |             63|11981|
# |             65|11648|
# |              4| 8198|
# |             39|33437|
# |             62|13135|
# |             12|20083|
# |             83| 4390|
# |             13|18624|
# |             14|19238|
# |             21|57239|
# |             66| 9366|
# |             91|  964|
# |             94|  353|
# |             74| 6727|
# |             72| 7049|
# |             76| 6459|
# |              2| 5992|
# |             80| 6316|
# |             50|28133|
# |             45|32646|
# |             57|16853|
# +---------------+-----+
#
# Er zitten hier records van kinderen 3, 8 jaar enzo. in die andere excel bestand die jij hebt gestuurd was alle info over 16+ mensen. Dus hier weeral al die kinderen verwijderen? Age_of_Casualty met waarde -1 zijn gevallen waar de leeftijd niet gekend is

# %%
def sort_age(age):
    age = int(age)
    if 16 <= age < 25:
        return "16-24"
    elif 25<=age <35:
        return "25-34"
    elif 35<= age <45:
        return "35-44"
    elif 45<= age <60:
        return "45-60"
    elif 60<= age <120:
        return "+60"
    elif 0 <= age <16:
        return "Child"
    else:
        return "Unknown"
sort_age(24)
joined = joined.withColumn("Age_of_Casualty", col("Age_of_Casualty").cast("int"))
joined = joined.withColumnRenamed("1st_Road_Class", "First_Road_Class")
joined2 = joined.rdd.map(lambda x: (x.Accident_Index, x.Longitude, 
                                    x.Latitude, x.Police_Force, x.Accident_Severity, x.Number_of_Vehicles, 
                                    x.Number_of_Casualties, x.Date, x.Day_of_Week, x.Time, x.First_Road_Class, 
                                    x.Road_Type, x.Speed_limit, x.Junction_Detail, x.Junction_Control, x.Light_Conditions, 
                                    x.Weather_Conditions,
                                    x.Road_Surface_Conditions, x.Special_Conditions_at_Site,
                                    x.Urban_or_Rural_Area, x.Did_Police_Officer_Attend_Scene_of_Accident, x.LSOA_of_Accident_Location, x.Casualty_Class, x.Sex_of_Casualty, x.Age_of_Casualty, x.Casualty_Severity, x.Pedestrian_Location, x.Car_Passenger, x.Casualty_Type, sort_age(x.Age_of_Casualty)))

joined2 = joined2.toDF(["Accident_Index", "Longitude" , "Latitude" , "Police_Force" , "Accident_Severity" ,
       "Number_of_Vehicles" , "Number_of_Casualties" , "Date" , "Day_of_Week" , "Time" , "1st_Road_Class" , "Road_Type" , "Speed_limit" , "Junction_Detail" , "Junction_Control" , "Light_Conditions" , "Weather_Conditions" , "Road_Surface_Conditions" , "Special_Conditions_at_Site" , "Urban_or_Rural_Area" ,
       "Did_Police_Officer_Attend_Scene_of_Accident" , "LSOA_of_Accident_Location" , "Casualty_Class" , "Sex_of_Casualty" , 
       "Age_of_Casualty" , "Casualty_Severity" , "Pedestrian_Location" , "Car_Passenger" , "Casualty_Type" , "Age_Cat"])

# %%
joined2.show(20, vertical= True)
# Out:
# -RECORD 0----------------------------------------------------
#  Accident_Index                              | 200501BS70192
#  Longitude                                   | -0.182199
#  Latitude                                    | 51.493723
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 04/05/2005
#  Day_of_Week                                 | 4
#  Time                                        | 16:10
#  1st_Road_Class                              | 5
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 0
#  Junction_Control                            | -1
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01002835
#  Casualty_Class                              | 3
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 19
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 8
#  Car_Passenger                               | 0
#  Casualty_Type                               | 0
#  Age_Cat                                     | 16-24
# -RECORD 1----------------------------------------------------
#  Accident_Index                              | 200501BS70293
#  Longitude                                   | -0.166319
#  Latitude                                    | 51.498152
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 15/06/2005
#  Day_of_Week                                 | 4
#  Time                                        | 10:10
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 3
#  Junction_Control                            | 2
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 2
#  Road_Surface_Conditions                     | 2
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01002819
#  Casualty_Class                              | 3
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 26
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 5
#  Car_Passenger                               | 0
#  Casualty_Type                               | 0
#  Age_Cat                                     | 25-34
# -RECORD 2----------------------------------------------------
#  Accident_Index                              | 200501BS70739
#  Longitude                                   | -0.200547
#  Latitude                                    | 51.492387
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 17/12/2005
#  Day_of_Week                                 | 7
#  Time                                        | 07:10
#  1st_Road_Class                              | 3
#  Road_Type                                   | 3
#  Speed_limit                                 | 40
#  Junction_Detail                             | 6
#  Junction_Control                            | 4
#  Light_Conditions                            | 4
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 2
#  LSOA_of_Accident_Location                   | E01002848
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 27
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 5
#  Age_Cat                                     | 25-34
# -RECORD 3----------------------------------------------------
#  Accident_Index                              | 200501CP00077
#  Longitude                                   | -0.095578
#  Latitude                                    | 51.511952
#  Police_Force                                | 48
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 05/05/2005
#  Day_of_Week                                 | 5
#  Time                                        | 15:40
#  1st_Road_Class                              | 5
#  Road_Type                                   | 2
#  Speed_limit                                 | 30
#  Junction_Detail                             | 7
#  Junction_Control                            | 4
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01000004
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 36
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 1
#  Age_Cat                                     | 35-44
# -RECORD 4----------------------------------------------------
#  Accident_Index                              | 200501CP00182
#  Longitude                                   | -0.096697
#  Latitude                                    | 51.512780
#  Police_Force                                | 48
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 17/08/2005
#  Day_of_Week                                 | 4
#  Time                                        | 11:34
#  1st_Road_Class                              | 5
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 6
#  Junction_Control                            | 2
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01000004
#  Casualty_Class                              | 3
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 28
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 1
#  Car_Passenger                               | 0
#  Casualty_Type                               | 0
#  Age_Cat                                     | 25-34
# -RECORD 5----------------------------------------------------
#  Accident_Index                              | 200501CP00197
#  Longitude                                   | -0.110603
#  Latitude                                    | 51.518041
#  Police_Force                                | 48
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 07/09/2005
#  Day_of_Week                                 | 4
#  Time                                        | 18:45
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 3
#  Junction_Control                            | 4
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01000917
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 35
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 4
#  Age_Cat                                     | 35-44
# -RECORD 6----------------------------------------------------
#  Accident_Index                              | 200501CP00212
#  Longitude                                   | -0.081157
#  Latitude                                    | 51.508750
#  Police_Force                                | 48
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 20/09/2005
#  Day_of_Week                                 | 3
#  Time                                        | 09:00
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 8
#  Junction_Control                            | 4
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01000004
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 2
#  Age_of_Casualty                             | 30
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 1
#  Age_Cat                                     | 25-34
# -RECORD 7----------------------------------------------------
#  Accident_Index                              | 200501CW10269
#  Longitude                                   | -0.118763
#  Latitude                                    | 51.512416
#  Police_Force                                | 1
#  Accident_Severity                           | 2
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 22/02/2005
#  Day_of_Week                                 | 3
#  Time                                        | 19:11
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 0
#  Junction_Control                            | -1
#  Light_Conditions                            | 4
#  Weather_Conditions                          | 3
#  Road_Surface_Conditions                     | 3
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01004735
#  Casualty_Class                              | 3
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 18
#  Casualty_Severity                           | 2
#  Pedestrian_Location                         | 7
#  Car_Passenger                               | 0
#  Casualty_Type                               | 0
#  Age_Cat                                     | 16-24
# -RECORD 8----------------------------------------------------
#  Accident_Index                              | 200501CW10359
#  Longitude                                   | -0.177424
#  Latitude                                    | 51.523145
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 15/03/2005
#  Day_of_Week                                 | 3
#  Time                                        | 15:48
#  1st_Road_Class                              | 6
#  Road_Type                                   | 6
#  Speed_limit                                 | 20
#  Junction_Detail                             | 0
#  Junction_Control                            | -1
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01004703
#  Casualty_Class                              | 3
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 3
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 5
#  Car_Passenger                               | 0
#  Casualty_Type                               | 0
#  Age_Cat                                     | Child
# -RECORD 9----------------------------------------------------
#  Accident_Index                              | 200501CW10368
#  Longitude                                   | -0.151478
#  Latitude                                    | 51.523098
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 20/03/2005
#  Day_of_Week                                 | 1
#  Time                                        | 02:39
#  1st_Road_Class                              | 3
#  Road_Type                                   | 3
#  Speed_limit                                 | 30
#  Junction_Detail                             | 6
#  Junction_Control                            | 2
#  Light_Conditions                            | 4
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01004717
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 2
#  Age_of_Casualty                             | 23
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 9
#  Age_Cat                                     | 16-24
# -RECORD 10---------------------------------------------------
#  Accident_Index                              | 200501CW10403
#  Longitude                                   | -0.167541
#  Latitude                                    | 51.517955
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 23/03/2005
#  Day_of_Week                                 | 4
#  Time                                        | 18:35
#  1st_Road_Class                              | 3
#  Road_Type                                   | 3
#  Speed_limit                                 | 30
#  Junction_Detail                             | 6
#  Junction_Control                            | 2
#  Light_Conditions                            | 4
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01004684
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 36
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 9
#  Age_Cat                                     | 35-44
# -RECORD 11---------------------------------------------------
#  Accident_Index                              | 200501CW10495
#  Longitude                                   | -0.170253
#  Latitude                                    | 51.529418
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 16/04/2005
#  Day_of_Week                                 | 7
#  Time                                        | 11:20
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 0
#  Junction_Control                            | -1
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01004725
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 44
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 9
#  Age_Cat                                     | 35-44
# -RECORD 12---------------------------------------------------
#  Accident_Index                              | 200501CW11050
#  Longitude                                   | -0.163837
#  Latitude                                    | 51.534803
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 14/07/2005
#  Day_of_Week                                 | 5
#  Time                                        | 11:20
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 6
#  Junction_Control                            | 2
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01004730
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 62
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 8
#  Age_Cat                                     | +60
# -RECORD 13---------------------------------------------------
#  Accident_Index                              | 200501EO00115
#  Longitude                                   | -0.180370
#  Latitude                                    | 51.561319
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 1
#  Date                                        | 23/01/2005
#  Day_of_Week                                 | 1
#  Time                                        | 11:27
#  1st_Road_Class                              | 5
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 6
#  Junction_Control                            | 4
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01000899
#  Casualty_Class                              | 2
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 39
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 2
#  Casualty_Type                               | 9
#  Age_Cat                                     | 35-44
# -RECORD 14---------------------------------------------------
#  Accident_Index                              | 200501EO40103
#  Longitude                                   | -0.129242
#  Latitude                                    | 51.569687
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 3
#  Number_of_Casualties                        | 2
#  Date                                        | 27/02/2005
#  Day_of_Week                                 | 1
#  Time                                        | 07:12
#  1st_Road_Class                              | 5
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 3
#  Junction_Control                            | 4
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 2
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01002759
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 2
#  Age_of_Casualty                             | 20
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 9
#  Age_Cat                                     | 16-24
# -RECORD 15---------------------------------------------------
#  Accident_Index                              | 200501EO40103
#  Longitude                                   | -0.129242
#  Latitude                                    | 51.569687
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 3
#  Number_of_Casualties                        | 2
#  Date                                        | 27/02/2005
#  Day_of_Week                                 | 1
#  Time                                        | 07:12
#  1st_Road_Class                              | 5
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 3
#  Junction_Control                            | 4
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 2
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01002759
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 53
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 9
#  Age_Cat                                     | 45-60
# -RECORD 16---------------------------------------------------
#  Accident_Index                              | 200501EO40294
#  Longitude                                   | -0.101655
#  Latitude                                    | 51.546043
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 1
#  Number_of_Casualties                        | 1
#  Date                                        | 29/04/2005
#  Day_of_Week                                 | 6
#  Time                                        | 23:26
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 0
#  Junction_Control                            | -1
#  Light_Conditions                            | 4
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01002791
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 2
#  Age_of_Casualty                             | 67
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 9
#  Age_Cat                                     | +60
# -RECORD 17---------------------------------------------------
#  Accident_Index                              | 200501EO40446
#  Longitude                                   | -0.122514
#  Latitude                                    | 51.536847
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 2
#  Date                                        | 10/05/2005
#  Day_of_Week                                 | 3
#  Time                                        | 13:35
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 3
#  Junction_Control                            | 4
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01000953
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 31
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 9
#  Age_Cat                                     | 25-34
# -RECORD 18---------------------------------------------------
#  Accident_Index                              | 200501EO40446
#  Longitude                                   | -0.122514
#  Latitude                                    | 51.536847
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 2
#  Number_of_Casualties                        | 2
#  Date                                        | 10/05/2005
#  Day_of_Week                                 | 3
#  Time                                        | 13:35
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 3
#  Junction_Control                            | 4
#  Light_Conditions                            | 1
#  Weather_Conditions                          | 1
#  Road_Surface_Conditions                     | 1
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 1
#  LSOA_of_Accident_Location                   | E01000953
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 35
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 9
#  Age_Cat                                     | 35-44
# -RECORD 19---------------------------------------------------
#  Accident_Index                              | 200501EO41123
#  Longitude                                   | -0.133763
#  Latitude                                    | 51.526235
#  Police_Force                                | 1
#  Accident_Severity                           | 3
#  Number_of_Vehicles                          | 3
#  Number_of_Casualties                        | 2
#  Date                                        | 08/10/2005
#  Day_of_Week                                 | 7
#  Time                                        | 19:40
#  1st_Road_Class                              | 3
#  Road_Type                                   | 6
#  Speed_limit                                 | 30
#  Junction_Detail                             | 6
#  Junction_Control                            | 2
#  Light_Conditions                            | 4
#  Weather_Conditions                          | 2
#  Road_Surface_Conditions                     | 2
#  Special_Conditions_at_Site                  | 0
#  Urban_or_Rural_Area                         | 1
#  Did_Police_Officer_Attend_Scene_of_Accident | 2
#  LSOA_of_Accident_Location                   | E01000852
#  Casualty_Class                              | 1
#  Sex_of_Casualty                             | 1
#  Age_of_Casualty                             | 58
#  Casualty_Severity                           | 3
#  Pedestrian_Location                         | 0
#  Car_Passenger                               | 0
#  Casualty_Type                               | 9
#  Age_Cat                                     | 45-60
# only showing top 20 rows

# %%
### Aantal accidenten per leeftijdscategorie
joined2.groupby("Age_Cat").count().show()
# Out:
# +-------+------+
# |Age_Cat| count|
# +-------+------+
# |    +60|224925|
# |Unknown| 45488|
# |  45-60|339903|
# |  35-44|338598|
# |  25-34|402662|
# |  Child|192400|
# |  16-24|514603|
# +-------+------+

# %%
### Aantal accidenten per Leeftijdscategorie en ernstigheid van het incident
joined2.groupby("Age_Cat", "Accident_Severity").count().show()
print("Zal proberen om er een staafdiagram van te maken")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-ee6964acfd1a> in <module>
#       1 ### Aantal accidenten per Leeftijdscategorie en ernstigheid van het incident
# ----> 2 joined2.groupby("Age_Cat", "Accident_Severity").count().show()
#       3 print("Zal proberen om er een staafdiagram van te maken")
#
# ~\anaconda3\lib\site-packages\pyspark\sql\dataframe.py in show(self, n, truncate, vertical)
#     482         """
#     483         if isinstance(truncate, bool) and truncate:
# --> 484             print(self._jdf.showString(n, 20, vertical))
#     485         else:
#     486             print(self._jdf.showString(n, int(truncate), vertical))
#
# ~\anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1301             proto.END_COMMAND_PART
#    1302
# -> 1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#
# ~\anaconda3\lib\site-packages\py4j\java_gateway.py in send_command(self, command, retry, binary)
#    1031         connection = self._get_connection()
#    1032         try:
# -> 1033             response = connection.send_command(command)
#    1034             if binary:
#    1035                 return response, self._create_connection_guard(connection)
#
# ~\anaconda3\lib\site-packages\py4j\java_gateway.py in send_command(self, command)
#    1198
#    1199         try:
# -> 1200             answer = smart_decode(self.stream.readline()[:-1])
#    1201             logger.debug("Answer received: {0}".format(answer))
#    1202             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Kijken naar de accidenten doorheen de tijd

# %%
print("refresh")

# %%
dfOfYears=sqlContext.sql("SELECT CAST(RIGHT(Date,6) as int) as Years from accidentTable group by RIGHT(Date,4)").collect()
dfOfYears=sqlContext.sql("SELECT Date as Years from accidentTable limit 5)").collect()
print(dfOfYears)
Yearslider=widgets.Dropdown(
    options=dfOfYears,
    description='Year:',
)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-39-3330d3176ef0> in <module>
# ----> 1 dfOfYears=sqlContext.sql("SELECT CAST(RIGHT(Date,6) as int) as Years from accidentTable group by RIGHT(Date,4)").collect()
#       2 dfOfYears=sqlContext.sql("SELECT Date as Years from accidentTable limit 5)").collect()
#       3 print(dfOfYears)
#       4 Yearslider=widgets.Dropdown(
#       5     options=dfOfYears,
#
# ~\anaconda3\lib\site-packages\pyspark\sql\context.py in sql(self, sqlQuery)
#     431         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     432         """
# --> 433         return self.sparkSession.sql(sqlQuery)
#     434
#     435     def table(self, tableName):
#
# ~\anaconda3\lib\site-packages\pyspark\sql\session.py in sql(self, sqlQuery)
#     721         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     722         """
# --> 723         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     724
#     725     def table(self, tableName):
#
# ~\anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# ~\anaconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# AnalysisException: expression 'accidenttable.`Date`' is neither present in the group by, nor is it an aggregate function. Add to group by or wrap in first() (or first_value) if you don't care which value you get.;
# Aggregate [right(Date#3927, 4)], [cast(right(Date#3927, 6) as int) AS Years#4714]
# +- SubqueryAlias accidenttable
#    +- Filter AtLeastNNulls(n, Accident_Index#3918,Longitude#3921,Latitude#3922,Police_Force#3923,Accident_Severity#3924,Number_of_Vehicles#3925,Number_of_Casualties#3926,Date#3927,Day_of_Week#3928,Time#3929,1st_Road_Class#3932,Road_Type#3934,Speed_limit#3935,Junction_Detail#3936,Junction_Control#3937,Light_Conditions#3942,Weather_Conditions#3943,Road_Surface_Conditions#3944,Special_Conditions_at_Site#3945,Urban_or_Rural_Area#3947,Did_Police_Officer_Attend_Scene_of_Accident#3948,LSOA_of_Accident_Location#3949)
#       +- Project [Accident_Index#3918, Longitude#3921, Latitude#3922, Police_Force#3923, Accident_Severity#3924, Number_of_Vehicles#3925, Number_of_Casualties#3926, Date#3927, Day_of_Week#3928, Time#3929, 1st_Road_Class#3932, Road_Type#3934, Speed_limit#3935, Junction_Detail#3936, Junction_Control#3937, Light_Conditions#3942, Weather_Conditions#3943, Road_Surface_Conditions#3944, Special_Conditions_at_Site#3945, Urban_or_Rural_Area#3947, Did_Police_Officer_Attend_Scene_of_Accident#3948, LSOA_of_Accident_Location#3949]
#          +- Relation[Accident_Index#3918,Location_Easting_OSGR#3919,Location_Northing_OSGR#3920,Longitude#3921,Latitude#3922,Police_Force#3923,Accident_Severity#3924,Number_of_Vehicles#3925,Number_of_Casualties#3926,Date#3927,Day_of_Week#3928,Time#3929,Local_Authority_(District)#3930,Local_Authority_(Highway)#3931,1st_Road_Class#3932,1st_Road_Number#3933,Road_Type#3934,Speed_limit#3935,Junction_Detail#3936,Junction_Control#3937,2nd_Road_Class#3938,2nd_Road_Number#3939,Pedestrian_Crossing-Human_Control#3940,Pedestrian_Crossing-Physical_Facilities#3941,... 8 more fields] csv

# %%
def f(x):
    dfOfYears=sqlContext.sql("SELECT * from accidentTable where RIGHT(Date,4)="+str(x[0])+" limit 1000")
    dfOfYears.show(1, vertical=True)
    UK_COORDINATES = (53.5500, -6.4333)
    map = folium.Map(location=UK_COORDINATES, zoom_start=5)
    for row in dfOfYears.collect():
        folium.Marker(location = [row.Latitude,row.Longitude]).add_to(map)
    display(map)
    return x
interact(f, x=Yearslider);
# Out:
# interactive(children=(Dropdown(description='Year:', options=(Row(Years=2012), Row(Years=2014), Row(Years=2013)…

# %%
df1 = sqlContext.sql("SELECT * from accidentTable")
UK_COORDINATES = (53.5500, -6.4333)
map = folium.Map(location=UK_COORDINATES, zoom_start=5)
## testing 
counter=0
#for indx,row in enumerate(df1.collect()):
#    print(indx)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_02b2561bb25443c18ee5ed4ebcc1caf7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_02b2561bb25443c18ee5ed4ebcc1caf7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_02b2561bb25443c18ee5ed4ebcc1caf7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_02b2561bb25443c18ee5ed4ebcc1caf7%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B53.55%2C%20-6.4333%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
